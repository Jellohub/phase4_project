# %% [markdown]
# # Flatiron School Phase 4 Project
#
# Student name: **Angelo Turri**
#
# Student pace: **self paced**
#
# Project finish date: ****
#
# Instructor name: **Mark Barbour**
#
# Blog post URL: **[x]**
#
# # INTRODUCTION
#
# ### Stakeholder
#
#
#
# ### Data: Origin & Usage
#
#
#
# ### Methods Justification & Value to Stakeholder
#
#
#
# ### Limitations
#
#
#
# ### Model Evaluation

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from IPython.display import clear_output, display_html
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.tsa.arima.model import ARIMA

# %%
data = pd.read_csv('data/zillow_data.csv')

# %%
data
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# ...

# %%
def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['RegionName', 'RegionID', 'SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
#     return melted.groupby('time').aggregate({'value':'mean'})
    melted.set_index('time', inplace=True)
    return melted

# %%
df = melt_data(data)

df['zipcount'] = df['RegionName'].map(df.RegionName.value_counts())

df = df[df.zipcount==265]
# Out:
# /var/folders/s6/jlb2zd1s5gq39tnl2x_y5z_r0000gn/T/ipykernel_12762/4249475289.py:12: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
# /var/folders/s6/jlb2zd1s5gq39tnl2x_y5z_r0000gn/T/ipykernel_12762/4249475289.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)

# %%
statistics = []
pvalues = []
cvs = []

for zipcode in df.RegionName.unique():
    
    zc = df[df.RegionName==zipcode].value

    dftest = adfuller(zc)

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    statistics.append(dfoutput['Test Statistic'])
    pvalues.append(dfoutput['p-value'])
    cvs.append(dfoutput['Critical Value (5%)'])

# %%
dfdf = pd.DataFrame({'zipcode': df.RegionName.unique(), 'adfuller_statistic': statistics, 'critical_value': cvs, 'adfuller_pvalue': pvalues}).sort_values(by='adfuller_statistic', ascending=False)

# %%
dfdf.tail(10)
# Out:
#       zipcode  adfuller_statistic  critical_value  adfuller_pvalue
# 4735    67213           -4.069771       -2.873219     1.086159e-03
# 7877    68112           -4.137978       -2.872809     8.376172e-04
# 2614    61614           -4.185254       -2.873219     6.978108e-04
# 9092    24630           -4.199839       -2.873033     6.593129e-04
# 2843    52501           -4.228075       -2.873125     5.903930e-04
# 768     29501           -4.285249       -2.873219     4.710779e-04
# 911     16001           -4.549904       -2.873266     1.596045e-04
# 5322    15644           -4.555433       -2.873266     1.559369e-04
# 4949    78735           -5.405801       -2.873219     3.293458e-06
# 4777    61081           -5.881707       -2.872897     3.067473e-07

# %%
df[df.RegionName==67213].value.plot()
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# # ACF and PACF

# %%
grouped = df.groupby('time').aggregate({'value':'mean'})

# %%
fig, ax = plt.subplots(figsize=(14,5))
plot_acf(grouped, lags=50, ax=ax);

fig, ax = plt.subplots(figsize=(14,5))
plot_pacf(grouped, lags=50, ax=ax);

# %% [markdown]
# # ARIMA modeling

# %%
ar_1 = ARIMA(df[df.RegionName==78758].value[:212], order=(1, 0, 1)).fit()
# Out:
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
# ...

# %%
ar_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                  value   No. Observations:                  212
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1533.819
# Date:                Mon, 01 Jan 2024   AIC                           3075.638
# Time:                        10:00:01   BIC                           3089.064
# Sample:                    04-01-1996   HQIC                          3081.065
#                          - 11-01-2013
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.35e+05   4.92e+04      2.745      0.006    3.86e+04    2.31e+05
# ar.L1          0.9992      0.003    314.004      0.000       0.993       1.005
# ma.L1          0.7873      0.044     17.856      0.000       0.701       0.874
# ...

# %%
valid = df[df.RegionName==78758].value[212:]
ar_1.predict(typ='levels')
# Out:
# 1996-04-01    135035.889156
# 1996-05-01    129002.542346
# 1996-06-01    127964.069783
# 1996-07-01    127210.928510
# 1996-08-01    126687.961933
#                   ...
# 2013-07-01    148575.015752
# 2013-08-01    149322.978364
# 2013-09-01    150520.569276
# 2013-10-01    152078.757047
# 2013-11-01    154067.633485
# Freq: MS, Name: predicted_mean, Length: 212, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.plot(df[df.RegionName==78758].value[:212], c='black', label='train')
ax.plot(df[df.RegionName==78758].value[212:], c='blue', label='valid')
ax.plot(ar_1.predict(typ='levels'), c='red', label='test')
ax.legend()

# %%
import time
st = time.time()

predictions = []
train = df[df.RegionName==78758].value[:212]

for n in range(53):
    ar = ARIMA(train, order=(1, 0, 0)).fit()
    prediction = ar.forecast()
    print(prediction)
    train = pd.concat([train, prediction])
    predictions.append(prediction)
    
elapsed_time = time.time() - st
print(elapsed_time)
# Out:
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
# ...

# %%
fig, ax = plt.subplots(figsize=(14,6))
ax.plot(df[df.RegionName==78758].value[:212], c='black', label='train')
ax.plot(df[df.RegionName==78758].value[212:], c='blue', label='valid')
ax.plot(train, c='red', label='test')
ax.legend()

# %%
ar = ARIMA(train.iloc[:213], order=(1, 0, 0)).fit()
# Out:
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
# ...

# %%
days = df[df.RegionName==78758].value.resample('1D').asfreq()

# %%
ar = ARIMA(days.loc['1996-04-01':'2013-10-31'].ffill(), order=(1, 0, 0)).fit()
# Out:
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'

# %%
ar.forecast()
# Out:
# 2013-11-01    153198.287363
# Freq: D, dtype: float64

# %%
df[df.RegionName==78758].value[:212]
# Out:
# time
# 1996-04-01    129000.0
# 1996-05-01    128300.0
# 1996-06-01    127500.0
# 1996-07-01    126900.0
# 1996-08-01    126300.0
#                 ...
# 2013-07-01    149000.0
# 2013-08-01    150000.0
# 2013-09-01    151400.0
# 2013-10-01    153200.0
# 2013-11-01    155000.0
# Name: value, Length: 212, dtype: float64

# %%
days.loc['1996-04-01':'2013-10-31']
# Out:
# time
# 1996-04-01    129000.0
# 1996-04-02         NaN
# 1996-04-03         NaN
# 1996-04-04         NaN
# 1996-04-05         NaN
#                 ...
# 2013-10-27         NaN
# 2013-10-28         NaN
# 2013-10-29         NaN
# 2013-10-30         NaN
# 2013-10-31         NaN
# Freq: D, Name: value, Length: 6423, dtype: float64
