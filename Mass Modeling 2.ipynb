# %% [markdown]
# # Flatiron School Phase 4 Project
#
# Student name: **Angelo Turri**
#
# Student pace: **self paced**
#
# Project finish date: ****
#
# Instructor name: **Mark Barbour**
#
# Blog post URL: **[x]**
#
# # INTRODUCTION
#
# ### Stakeholder
#
#
#
# ### Data: Origin & Usage
#
#
#
# ### Methods Justification & Value to Stakeholder
#
#
#
# ### Limitations
#
#
#
# ### Model Evaluation

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from statsmodels.tsa.stattools import adfuller, kpss
from sklearn.metrics import mean_squared_error, mean_absolute_error
from IPython.display import clear_output, display_html
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from statsmodels.tsa.stattools import pacf, acf
from statsmodels.tsa.arima.model import ARIMA
import time
from statsmodels.tsa.statespace.sarimax import SARIMAX

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('data/zillow_data.csv')

# %%
def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['RegionName', 'RegionID', 'SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    melted.set_index('time', inplace=True)
    return melted

# %%
# Changing from wide to long format
df = melt_data(data)

# Making sure each zipcode in the dataset has the full 265 months of data
df['zipcount'] = df['RegionName'].map(df.RegionName.value_counts())
df = df[df.zipcount==265]

# Changing the name of the zipcode column to accurately reflect what it contains.
df['zipcode'] = df['RegionName']
df.drop(['RegionName'], axis=1, inplace=True)

# %%
df = df.query("State=='MI'")

# %%
ad_2012 = df[df.index>'2011-12-1'].copy()
grouped = ad_2012.groupby('time').aggregate({'value':'mean'})

# %% [markdown]
# # General trend of house price data
#
# You can see the effects of the 2008 housing market crash on what was an otherwise ever-increasing series of data points. This crash was an anomaly in the general upward trend of housing prices. I will only keep data after 2012, which is when the housing market slump seemed to be over.

# %%
grouped = df.groupby('time').aggregate({'value':'mean'})

# %%
fig, ax = plt.subplots(figsize=(15,7))
grouped.value.plot()
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# # Data after the housing market crash
#
# As expected, we have removed the anomalous housing market crash and what remains is a normal, linearly trending group of data for housing prices. This is the data that we will use for our models.

# %%
# Keeping data during and after 2012
ad_2012 = df[df.index>'2011-12-1'].copy()
grouped = ad_2012.groupby('time').aggregate({'value':'mean'})

# %%
fig, ax = plt.subplots(figsize=(15,7))
grouped.value.plot()
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# # Number of zipcodes
#
# Our stakeholder wants us to examine all the zipcodes in the dataset. There are 13,684 zipcodes in total, spread out across all 50 states. To find out which zipcodes are the best ones to invest in, we will have to forecast housing prices in each zipcode, which means fitting at least one model to each. ARIMA and SARMIAX do not take categorical exogenous variables, only numerical ones, which excludes the zipcode variable from being included in either type of model.

# %%
df.dtypes
# Out:
# RegionID        int64
# SizeRank        int64
# City           object
# State          object
# Metro          object
# CountyName     object
# value         float64
# zipcount        int64
# zipcode         int64
# dtype: object

# %%
df.zipcode.nunique()
# Out:
# 453

# %%
df.State.nunique()
# Out:
# 1

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.hist(ad_2012.value, bins=100);

# %% [markdown]
# # Kinds of zipcodes
#
# Although the aggregated dataset shows a clear upwards trend, not all zipcodes follow this pattern. There are zipcodes that follow a very linear upward trajectory, but there are others that follow a more cyclical path. This suggests that there is no one model that will fit well to all the zipcodes.

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(ad_2012[ad_2012.zipcode==18702].value)

fig, ax = plt.subplots(figsize=(15,7))
ad_2012[ad_2012.zipcode==77084].value.plot()

fig, ax = plt.subplots(figsize=(15,7))
ad_2012[ad_2012.zipcode==61611].value.plot();

# %% [markdown]
# # Naive Models
#
# The baseline naive model we will use is a model with all values shifted forward by 1.
#
# A successful model will successfully extract all temporal components from each zipcode's time series, and the accompanying model residuals will be stationary.
#
# Only 46% of the models actually reduced their accompanying time series to a white noise model. The average mse of our models was 12.7 million. This will be our benchmark for other models.

# %%
st = time.time()

mses = []
ad_pvalues, kpss_pvalues = [], []
residuals_list = []

for i in range(len(ad_2012.zipcode.unique())):
    
    zc = ad_2012.zipcode.unique()[i]
    zipcode = ad_2012[ad_2012.zipcode==zc].value
    shifted = zipcode.shift(1)[1:]
    
    mse = mean_squared_error(zipcode[1:], shifted)
    mses.append(mse)
    
    residuals = shifted-zipcode[1:]
    residuals_list.append(residuals)
    
    dftest = adfuller(residuals)
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    ad_pvalues.append(dfoutput['p-value'])
    
    kpsstest = kpss(residuals, regression='ct')
    kpss_pvalues.append(kpsstest[1])
    
    clear_output(wait=True)
    print(f"Zipcode #{i+1}/{ad_2012.zipcode.nunique()} done.")
    
elapsed_time = time.time() - st
print("Execution time: " + str(elapsed_time) + " seconds")
# Out:
# Zipcode #453/453 done.
# Execution time: 1.6396090984344482 seconds

# %%
naive_model_df = pd.DataFrame({'zipcode': ad_2012.zipcode.unique(), 
                               'mse': mses, 
                               'adfuller_pvalue': ad_pvalues, 
                               'kpss_pvalue': kpss_pvalues, 
                               'residuals': residuals_list})

# %%
len(naive_model_df.query("adfuller_pvalue<0.05 & kpss_pvalue>0.05"))/len(naive_model_df)
# Out:
# 0.5761589403973509

# %%
naive_model_df.mse.mean()
# Out:
# 2213863.723325975

# %%
len(naive_model_df.query("mse>1000000000"))
# Out:
# 0

# %%
naive_model_df.query("mse<1000000000").mse.mean()
# Out:
# 2213863.723325975

# %%
naive_model_df.query("mse<100000000").boxplot(column=['mse'])
# Out:
# <Axes: >

# %% [markdown]
# # Deciding our parameters for the ARIMA model
#
# Looking at our autocorrelation and partial autocorrelation plots, it looks like we should at least make one difference on the data. Let's perform the difference and then re-evaluate the partial and autocorrelation plots.

# %%
plot_acf(grouped.value);
plot_pacf(grouped.value);

# %% [markdown]
# # Differencing the series
#
# After differencing the aggregated series, the number of significant lags went down from 7 to 3, two of which are well outside the significance boundary. Our partial autocorrelation plot remains the same.
#
# These suggest that our first model should have at least two AR terms, one MA term, and one difference.

# %%
plot_acf(grouped.diff(1).value[1:]);
plot_pacf(grouped.diff(1).value[1:]);

# %% [markdown]
# # Running ARIMA models of order (1,1,1)
#
# Using one AR term, one MA term, and one difference per the PACF and ACF plots above.

# %%
st = time.time()

ad_pvalues, kpss_pvalues = [], []
model_type = []
predictions_list = []
forecasts = []
original = []

for i in range(len(ad_2012.zipcode.unique())):
    
    zc = ad_2012.zipcode.unique()[i]
    zipcode = ad_2012[ad_2012.zipcode==zc].value
    original.append(zipcode)
    print(f"Zipcode: {zc}")

    model = ARIMA(zipcode, order=(1, 1, 1)).fit()
    model_type.append('1 MA term')
            
    predictions = model.predict()
    predictions_list.append(predictions)
    
    forecast = model.get_forecast(steps=28).predicted_mean
    forecasts.append(forecast)
    
    dftest = adfuller(residuals)
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    ad_pvalues.append(dfoutput['p-value'])
    
    kpsstest = kpss(residuals, regression='ct')
    kpss_pvalues.append(kpsstest[1])
    
    clear_output(wait=True)
    print(f"Zipcode #{i+1}/{ad_2012.zipcode.nunique()} done.")
    
elapsed_time = time.time() - st
print("Execution time: " + str(elapsed_time) + " seconds")
# Out:
# Zipcode #453/453 done.
# Execution time: 16.57148814201355 seconds

# %%
arima_model_df = pd.DataFrame({'zipcode': ad_2012.zipcode.unique(), 
                               'model_type': model_type,
                               'mse': mses, 
                               'adfuller_pvalue': ad_pvalues, 
                               'kpss_pvalue': kpss_pvalues, 
                               'residuals': residuals_list, 
                               'predictions': predictions_list, 
                               'forecast': forecasts, 
                               'original': original})

# %%
arima_model_df
# Out:
#      zipcode model_type           mse  adfuller_pvalue  kpss_pvalue  \
# 0      48197  1 MA term  5.349049e+05     1.070224e-02     0.100000
# 1      48180  1 MA term  1.393025e+05     1.106364e-02     0.100000
# 2      48103  1 MA term  1.132117e+06     1.046541e-02     0.100000
# 3      48185  1 MA term  2.117551e+05     8.016877e-03     0.060068
# 4      48823  1 MA term  1.359269e+06     2.741195e-03     0.100000
# ..       ...        ...           ...              ...          ...
# 448    49322  1 MA term  1.711888e+06     6.200563e-04     0.100000
# 449    49724  1 MA term  2.421531e+05     3.752761e-02     0.100000
# 450    49716  1 MA term  1.471668e+06     9.337882e-02     0.049803
# 451    49725  1 MA term  6.466482e+05     1.639080e-03     0.100000
# 452    49710  1 MA term  7.204709e+05     1.107308e-08     0.100000
#
#                                              residuals  \
# 0    2012-02-01     348.602170
# 2012-03-01      38.2...
# 1    2012-02-01     13.788105
# 2012-03-01    412.450...
# 2    2012-02-01     987.325148
# 2012-03-01     771.2...
# 3    2012-02-01    1046.415299
# 2012-03-01    1070.6...
# 4    2012-02-01     900.037472
# 2012-03-01     200.0...
# ..                                                 ...
# 448  2012-02-01    2004.513407
# 2012-03-01     373.3...
# 449  2012-02-01    1120.834702
# 2012-03-01     904.9...
# 450  2012-02-01    4501.923206
# 2012-03-01    2497.9...
# 451  2012-02-01    1148.652839
# 2012-03-01     839.0...
# 452  2012-02-01     706.039039
# 2012-03-01     593.7...
#
#                                            predictions  \
# 0    2012-02-01    119548.602170
# 2012-03-01    1204...
# 1    2012-02-01    49713.788105
# 2012-03-01    50312...
# 2    2012-02-01    218787.325148
# 2012-03-01    2196...
# 3    2012-02-01     71746.415299
# 2012-03-01     715...
# 4    2012-02-01    144800.037472
# 2012-03-01    1439...
# ..                                                 ...
# 448  2012-02-01    64004.513407
# 2012-03-01    61773...
# 449  2012-02-01    79220.834702
# 2012-03-01    78304...
# 450  2012-02-01    103601.923206
# 2012-03-01     990...
# 451  2012-02-01    75948.652839
# 2012-03-01    75039...
# 452  2012-02-01    53806.039039
# 2012-03-01    53093...
#
#                                               forecast  \
# 0    2018-05-01    213549.708027
# 2018-06-01    2147...
# 1    2018-05-01     96827.072828
# 2018-06-01     974...
# 2    2018-05-01    371770.907546
# 2018-06-01    3737...
# 3    2018-05-01    143353.061712
# 2018-06-01    1443...
# 4    2018-05-01    194900.059974
# 2018-06-01    1949...
# ..                                                 ...
# 448  2018-05-01    76491.097060
# 2018-06-01    76485...
# 449  2018-05-01     96425.008501
# 2018-06-01     966...
# 450  2018-05-01    122298.036160
# 2018-06-01    1222...
# 451  2018-05-01     95248.017017
# 2018-06-01     954...
# 452  2018-05-01    79793.922759
# 2018-06-01    79799...
#
#                                               original
# 0    time
# 2012-01-01    118300.0
# 2012-02-01    1192...
# 1    time
# 2012-01-01    49100.0
# 2012-02-01    49700...
# 2    time
# 2012-01-01    216900.0
# 2012-02-01    2178...
# 3    time
# 2012-01-01     70800.0
# 2012-02-01     707...
# 4    time
# 2012-01-01    144800.0
# 2012-02-01    1439...
# ..                                                 ...
# 448  time
# 2012-01-01    62000.0
# 2012-02-01    62000...
# 449  time
# 2012-01-01    79000.0
# 2012-02-01    78100...
# 450  time
# 2012-01-01    103600.0
# 2012-02-01     991...
# 451  time
# 2012-01-01    75700.0
# 2012-02-01    74800...
# 452  time
# 2012-01-01    53800.0
# 2012-02-01    53100...
#
# [453 rows x 9 columns]

# %%
len(arima_model_df.query("adfuller_pvalue<0.05 & kpss_pvalue>0.05"))/len(naive_model_df)
# Out:
# 0.6114790286975718

# %%
arima_model_df.mse.mean()
# Out:
# 1328207.7942073783

# %%
len(arima_model_df.query("mse>1000000000"))
# Out:
# 0

# %%
arima_model_df.query("mse<1000000000").mse.mean()
# Out:
# 1328207.7942073783

# %%
row = arima_model_df.iloc[26]

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(row.original, c='blue', label='original')
ax.plot(row.predictions, c='red', label='predictions')
ax.plot(row.forecast, c='green', label='forecast')

# %% [markdown]
# # Train-test split
#
# The models appear to be in working order. However, we have not implemented a train-test split. We will include all years from 2012 – 2017 for the training data, and everything after will be for the test portion of our dataset.

# %% [markdown]
# # Adding a seasonal element
#
# Although our results are much improved, what if we had a seasonal element?

# %%
seasonal_orders = []

P_params = [0,1]
D_params = [0,1]
Q_params = [0,1]
m_params = [12]

for P in P_params:
    for D in D_params:
        for Q in Q_params:
            for m in m_params:
                so = [P, D, Q, m]
                seasonal_orders.append(so)

# %%
st = time.time()

mses = []
ad_pvalues, kpss_pvalues = [], []
residuals_list = []
predictions_list = []
forecasts = []
original = []
zipcodes = []

for i in range(len(ad_2012.zipcode.unique())):
    
    for x in range(len(seasonal_orders)):
        
        so = seasonal_orders[x]
    
        zc = ad_2012.zipcode.unique()[i]
        zipcode = ad_2012[ad_2012.zipcode==zc].value
        zipcodes.append(zc)
        original.append(zipcode)
        print(f"Zipcode #{i+1}/{ad_2012.zipcode.nunique()}")

        model = SARIMAX(zipcode, order=(1, 1, 1), seasonal_order=(so)).fit(disp=False, method='nm')

        predictions = model.predict()[1:]
        predictions_list.append(predictions)

        forecast = model.get_forecast(steps=28).predicted_mean
        forecasts.append(forecast)

        mse = mean_squared_error(zipcode[1:], predictions)
        mses.append(mse)

        residuals = predictions-zipcode[1:]
        residuals_list.append(residuals)

        dftest = adfuller(residuals)
        dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
        ad_pvalues.append(dfoutput['p-value'])

        kpsstest = kpss(residuals, regression='ct')
        kpss_pvalues.append(kpsstest[1])
        
        clear_output(wait=True)
        print(f"Seasonal order #{x+1}/{8} done.")

    clear_output(wait=True)
    print(f"Zipcode #{i+1}/{ad_2012.zipcode.nunique()} done.")
    
elapsed_time = time.time() - st
print("Execution time: " + str(elapsed_time) + " seconds")
# Out:
# Zipcode #453/453 done.
# Execution time: 466.27995014190674 seconds

# %%
zipcodes = []

for zc in ad_2012.zipcode.unique():
    for i in range(8):
        zipcodes.append(zc)

# %%
ht_sarimax_model_df = pd.DataFrame({'zipcode': zipcodes, 
                                    'seasonal_order': seasonal_orders*453,
                                   'mse': mses, 
                                   'adfuller_pvalue': ad_pvalues, 
                                   'kpss_pvalue': kpss_pvalues, 
                                   'residuals': residuals_list, 
                                   'predictions': predictions_list, 
                                   'forecast': forecasts, 
                                   'original': original})

# %%
ht_sarimax_model_df
# Out:
#       zipcode seasonal_order           mse  adfuller_pvalue  kpss_pvalue  \
# 0       48197  [0, 0, 0, 12]  1.013502e+06     1.823039e-02          0.1
# 1       48197  [0, 0, 1, 12]  2.050534e+06     9.337693e-04          0.1
# 2       48197  [0, 1, 0, 12]  9.014118e+07     5.049259e-14          0.1
# 3       48197  [0, 1, 1, 12]  6.793088e+07     9.226058e-02          0.1
# 4       48197  [1, 0, 0, 12]  2.010459e+06     2.706806e-04          0.1
# ...       ...            ...           ...              ...          ...
# 3619    49710  [0, 1, 1, 12]  2.065170e+07     3.091158e-01          0.1
# 3620    49710  [1, 0, 0, 12]  8.644301e+05     3.723649e-02          0.1
# 3621    49710  [1, 0, 1, 12]  5.808505e+05     3.821271e-04          0.1
# 3622    49710  [1, 1, 0, 12]  1.781423e+07     7.991193e-16          0.1
# 3623    49710  [1, 1, 1, 12]  1.258337e+07     1.237413e-15          0.1
#
#                                               residuals  \
# 0     2012-02-01    1407.248099
# 2012-03-01     948.3...
# 1     2012-02-01     801.025912
# 2012-03-01   -2228.7...
# 2     2012-02-01    -645.645828
# 2012-03-01   -1416.4...
# 3     2012-02-01    1288.886969
# 2012-03-01   -2666.2...
# 4     2012-02-01    -669.923915
# 2012-03-01   -1324.3...
# ...                                                 ...
# 3619  2012-02-01    2125.852048
# 2012-03-01    -723.6...
# 3620  2012-02-01    1012.296930
# 2012-03-01     286.9...
# 3621  2012-02-01    1260.340857
# 2012-03-01     377.2...
# 3622  2012-02-01      56.406392
# 2012-03-01     205.4...
# 3623  2012-02-01      75.653383
# 2012-03-01     408.0...
#
#                                             predictions  \
# 0     2012-02-01    120607.248099
# 2012-03-01    1213...
# 1     2012-02-01    120001.025912
# 2012-03-01    1181...
# 2     2012-02-01    118554.354172
# 2012-03-01    1189...
# 3     2012-02-01    120488.886969
# 2012-03-01    1177...
# 4     2012-02-01    118530.076085
# 2012-03-01    1190...
# ...                                                 ...
# 3619  2012-02-01    55225.852048
# 2012-03-01    51776...
# 3620  2012-02-01    54112.296930
# 2012-03-01    52786...
# 3621  2012-02-01    54360.340857
# 2012-03-01    52877...
# 3622  2012-02-01    53156.406392
# 2012-03-01    52705...
# 3623  2012-02-01    53175.653383
# 2012-03-01    52908...
#
#                                                forecast  \
# 0     2018-05-01    212741.983634
# 2018-06-01    2131...
# 1     2018-05-01    212382.104456
# 2018-06-01    2124...
# 2     2018-05-01    213697.241319
# 2018-06-01    2161...
# 3     2018-05-01    213695.033038
# 2018-06-01    2159...
# 4     2018-05-01    212357.651900
# 2018-06-01    2124...
# ...                                                 ...
# 3619  2018-05-01    81312.037332
# 2018-06-01    81582...
# 3620  2018-05-01    79650.496149
# 2018-06-01    79721...
# 3621  2018-05-01    80109.817051
# 2018-06-01    80149...
# 3622  2018-05-01    81450.097389
# 2018-06-01    81642...
# 3623  2018-05-01    81463.556059
# 2018-06-01    81695...
#
#                                                original
# 0     time
# 2012-01-01    118300.0
# 2012-02-01    1192...
# 1     time
# 2012-01-01    118300.0
# 2012-02-01    1192...
# 2     time
# 2012-01-01    118300.0
# 2012-02-01    1192...
# 3     time
# 2012-01-01    118300.0
# 2012-02-01    1192...
# 4     time
# 2012-01-01    118300.0
# 2012-02-01    1192...
# ...                                                 ...
# 3619  time
# 2012-01-01    53800.0
# 2012-02-01    53100...
# 3620  time
# 2012-01-01    53800.0
# 2012-02-01    53100...
# 3621  time
# 2012-01-01    53800.0
# 2012-02-01    53100...
# 3622  time
# 2012-01-01    53800.0
# 2012-02-01    53100...
# 3623  time
# 2012-01-01    53800.0
# 2012-02-01    53100...
#
# [3624 rows x 9 columns]

# %%
empty_df = pd.DataFrame()

# %%
for zc in ht_sarimax_model_df.zipcode.unique():
    sarimax = ht_sarimax_model_df[ht_sarimax_model_df.zipcode==zc]
    empty_df = pd.concat([empty_df, sarimax.sort_values(by='mse').iloc[0]], axis=1)

# %%
empty_df = empty_df.transpose()

# %%
empty_df.query("mse<1000000000").mse.mean()
# Out:
# 2030400.8598395628
